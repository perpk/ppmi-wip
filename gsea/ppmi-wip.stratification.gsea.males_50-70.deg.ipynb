# %%
import pandas as pd
import anndata as ad
import numpy as np
import gseapy

# %%
ppmi_ad = ad.read_h5ad("/Users/kpax/Documents/aep/study/MSC/lab/PPMI_Project_133_RNASeq/ppmi_adata.h5ad")

# %%
consolidated_gsea_across_visits = "/Users/kpax/Documents/aep/study/MSC/lab/PPMI_Project_133_RNASeq/gsea/dge_enr_results/enr_results_sorted_common_terms_Male_50-70.csv"

# %%
mask = ((ppmi_ad.obs['Age_Group'] == '50-70') &
        (ppmi_ad.obs['Gender'] == 'Male') &
        (ppmi_ad.obs['Diagnosis'].isin(['PD', 'Control'])))
ppmi_ad = ppmi_ad[mask]

# %%
symbol_ensembl_mapping = ppmi_ad.varm['symbol_ensembl_mapping']

# %%
gsea_df = pd.read_csv(consolidated_gsea_across_visits, index_col=0)

# %%
gsea_df = gsea_df.drop_duplicates(subset='Term')

# %%
gsea_df = gsea_df[gsea_df['Adjusted P-value'] <= 0.05]

# %%
gsea_df.shape
# Out:
# (14, 11)

# %%
gsea_df
# Out:
#      Unnamed: 0                                 Gene_set  \
# 358         422                         ARCHS4_TFs_Coexp
# 359         424                         ARCHS4_TFs_Coexp
# 361         428                         ARCHS4_TFs_Coexp
# 360         425                         ARCHS4_TFs_Coexp
# 362         426                         ARCHS4_TFs_Coexp
# 363        3336  TF_Perturbations_Followed_by_Expression
# 714          69                             OMIM_Disease
# 364        1301                                ChEA_2022
# 365         594                                ChEA_2013
# 716          31                 Human_Phenotype_Ontology
# 715          32                 Human_Phenotype_Ontology
# 367          97                 Human_Phenotype_Ontology
# 717          37                 Human_Phenotype_Ontology
# 369         439                         ARCHS4_TFs_Coexp
#
#                                             Term Overlap       P-value  \
# 358            MXI1 human tf ARCHS4 coexpression  10/299  1.348686e-15
# 359           JAZF1 human tf ARCHS4 coexpression   8/299  1.335258e-11
# 361            TAL1 human tf ARCHS4 coexpression   7/299  9.036820e-10
# 360            E2F2 human tf ARCHS4 coexpression   7/299  9.036820e-10
# 362           GATA1 human tf ARCHS4 coexpression   7/299  9.036820e-10
# 363       LIN28 OE CD34 HUMAN GSE93256 RNASEQ UP   6/411  3.106441e-07
# 714                                       anemia    2/61  4.944295e-04
# 364     EKLF 21900194 ChIP-Seq ERYTHROCYTE Mouse  7/1055  4.933666e-06
# 365              EKLF-21900194-ERYTHROCYTE-MOUSE  7/1239  1.425374e-05
# 716                  Broad forehead (HP:0000337)    2/77  7.867630e-04
# 715         Bruising susceptibility (HP:0000978)    2/79  8.279437e-04
# 367  Autosomal dominant inheritance (HP:0000006)  6/1134  1.053285e-04
# 717                Malar flattening (HP:0000272)   2/187  4.524432e-03
# 369           FOXO4 human tf ARCHS4 coexpression   3/299  1.317257e-03
#
#      Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 358      2.306253e-13            0                     0  136.304498
# 359      7.610973e-10            0                     0   77.345115
# 361      2.207566e-08            0                     0   59.011558
# 360      2.207566e-08            0                     0   59.011558
# 362      2.207566e-08            0                     0   59.011558
# 363      1.248789e-04            0                     0   32.230453
# 714      4.944295e-04            0                     0   75.065913
# 364      1.090340e-03            0                     0   15.810949
# 365      1.090411e-03            0                     0   13.318892
# 716      1.766280e-03            0                     0   59.004444
# 715      1.766280e-03            0                     0   57.466089
# 367      2.501553e-03            0                     0   11.144799
# 717      6.858081e-03            0                     0   23.788589
# 369      1.185532e-02            0                     0   16.629223
#
#      Combined Score                                              Genes
# 358     4667.017736  EPB42;OR2W3;EPB41;TRIM58;E2F2;SLC4A1;RUNDC3A;S...
# 359     1936.668413   EPB42;OR2W3;EPB41;TRIM58;RUNDC3A;SPTB;ANK1;OSBP2
# 361     1228.888768           EPB42;OR2W3;ITGB3;TRIM58;E2F2;SPTB;OSBP2
# 360     1228.888768          EPB42;OR2W3;TRIM58;SLC4A1;SPTB;ANK1;OSBP2
# 362     1228.888768          SLC6A8;EPB42;OR2W3;TRIM58;SPTB;ANK1;OSBP2
# 363      482.961016                TRIM58;E2F2;SLC4A1;SPTB;ANK1;TENT5C
# 714      571.409686                                          HBA2;HBA1
# 364      193.200763           EPB42;EPB41;TRIM58;E2F2;SLC4A1;SPTB;ANK1
# 365      148.618741           EPB42;EPB41;TRIM58;E2F2;SLC4A1;SPTB;ANK1
# 716      421.739196                                          HBA2;HBA1
# 715      407.811864                                          HBA2;HBA1
# 367      102.068818                  EPB41;ITGB3;KRT1;SLC4A1;SPTB;ANK1
# 717      128.417064                                          HBA2;HBA1
# 369      110.288391                                    EPB42;SPTB;ANK1
