# %%
import anndata as ad
ppmi_ad = ad.read_h5ad("/Users/kpax/Documents/aep/study/MSC/lab/PPMI_Project_133_RNASeq/ppmi_adata.h5ad")

# %%
mask = ((ppmi_ad.obs['Age_Group'] == '30-50') &
        (ppmi_ad.obs['Gender'] == 'Male') &
        (ppmi_ad.obs['Diagnosis'].isin(['PD', 'Control'])) &
        (ppmi_ad.obs['Visit'] == 'BL'))

# %%
ppmi_ad = ppmi_ad[mask]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import (
    VarianceThreshold,
    SelectKBest,
    f_classif,
    mutual_info_classif,
    chi2
)
from skfeature.function.similarity_based import fisher_score
from sklearn.preprocessing import KBinsDiscretizer, StandardScaler

# %%
X = pd.DataFrame(ppmi_ad.layers['counts_log2'], columns=ppmi_ad.var_names)
y = (ppmi_ad.obs['Diagnosis'] == 'PD').astype(int)

# %%
var_selector = VarianceThreshold(threshold=0.1)
X_highvar = var_selector.fit_transform(X)
selected_genes = X.columns[var_selector.get_support()]
print(f"After variance threshold: {len(selected_genes)} genes remaining")
# Out:
# After variance threshold: 56249 genes remaining

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_highvar)

# %%
n_top_genes = 20000

# %% [markdown]
# ### Anova F-Value

# %%
anova_scores, _ = f_classif(X_scaled, y)
top_indices_anovaf = np.argsort(anova_scores)[-n_top_genes:][::-1]
anova_selected_genes = selected_genes[top_indices_anovaf]
anova_selected_genes
# Out:
# Index(['ENSG00000273011.1', 'ENSG00000272741.1', 'ENSG00000203321.2',
#        'ENSG00000273739.1', 'ENSG00000280064.1', 'ENSG00000139044.11',
#        'ENSG00000270585.1', 'ENSG00000232028.1', 'ENSG00000214708.4',
#        'ENSG00000211790.2',
#        ...
#        'ENSG00000248423.1', 'ENSG00000183206.17', 'ENSG00000182768.8',
#        'ENSG00000166333.13', 'ENSG00000234110.1', 'ENSG00000242197.2',
#        'ENSG00000234748.1', 'ENSG00000207036.1', 'ENSG00000201277.1',
#        'ENSG00000230011.2'],
#       dtype='object', length=20000)

# %% [markdown]
# ### Chi-Squared

# %%
discretizer = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')
X_processed = discretizer.fit_transform(X_scaled)
chi2_scores, _ = chi2(X_processed, y)
top_indices_chi2 = np.argsort(chi2_scores)[-n_top_genes:][::-1]
chi2_selected_genes = selected_genes[top_indices_chi2]
chi2_selected_genes
# Out:
# Index(['ENSG00000272741.1', 'ENSG00000273739.1', 'ENSG00000207559.1',
#        'ENSG00000223619.1', 'ENSG00000260444.1', 'ENSG00000207512.1',
#        'ENSG00000221275.1', 'ENSG00000201867.1', 'ENSG00000270472.2',
#        'ENSG00000270585.1',
#        ...
#        'ENSG00000108375.12', 'ENSG00000223612.3', 'ENSG00000225854.2',
#        'ENSG00000172967.7', 'ENSG00000207573.1', 'ENSG00000260955.2',
#        'ENSG00000131373.14', 'ENSG00000171813.13', 'ENSG00000085998.13',
#        'ENSG00000268357.1'],
#       dtype='object', length=20000)

# %% [markdown]
# ### Mutual Information

# %%
mutual_info_scores = mutual_info_classif(X_scaled, y)
top_indices_mutual_info = np.argsort(mutual_info_scores)[-n_top_genes:][::-1]
mutual_info_selected_genes = selected_genes[top_indices_mutual_info]
mutual_info_selected_genes
# Out:
# Index(['ENSG00000100987.14', 'ENSG00000215120.2', 'ENSG00000276824.1',
#        'ENSG00000123201.14', 'ENSG00000225259.4', 'ENSG00000169860.6',
#        'ENSG00000171873.7', 'ENSG00000130294.16', 'ENSG00000266899.2',
#        'ENSG00000258407.1',
#        ...
#        'ENSG00000130741.10', 'ENSG00000197275.13', 'ENSG00000254738.1',
#        'ENSG00000250071.1', 'ENSG00000282924.1', 'ENSG00000231249.1',
#        'ENSG00000186960.10', 'ENSG00000270747.1', 'ENSG00000231621.1',
#        'ENSG00000205959.3'],
#       dtype='object', length=20000)

# %% [markdown]
# ### Fisher's Score

# %%
from skfeature.function.similarity_based import fisher_score
fisher_score = fisher_score.fisher_score(X_scaled, np.asarray(y))
top_indices_fisher = np.argsort(fisher_score)[-n_top_genes:][::-1]
fisher_selected_genes = selected_genes[top_indices_fisher]
fisher_selected_genes
# Out:
# Index(['ENSG00000263041.1', 'ENSG00000198746.12', 'ENSG00000262609.1',
#        'ENSG00000230803.1', 'ENSG00000273957.1', 'ENSG00000275201.1',
#        'ENSG00000225450.1', 'ENSG00000237914.5', 'ENSG00000230312.2',
#        'ENSG00000259029.1',
#        ...
#        'ENSG00000177426.20', 'ENSG00000218891.4', 'ENSG00000259842.2',
#        'ENSG00000243104.1', 'ENSG00000236005.1', 'ENSG00000248440.1',
#        'ENSG00000171773.2', 'ENSG00000136717.14', 'ENSG00000232869.2',
#        'ENSG00000257587.1'],
#       dtype='object', length=20000)

# %% [markdown]
# ### Overlapping Genes

# %%
from venny4py.venny4py import *

sets = {
    'ANOVA': set(anova_selected_genes),
    'Chi-Squared': set(chi2_selected_genes),
    'Mutual Information': set(mutual_info_selected_genes),
    'Fisher\'s Score': set(fisher_selected_genes)
}
venny4py(sets=sets)

# %%
common_genes = set(anova_selected_genes) & set(chi2_selected_genes) & set(mutual_info_selected_genes) & set(fisher_selected_genes)
print(f"Number of common genes across methods: {len(common_genes)}")
# Out:
# Number of common genes across methods: 2176
# Common genes:
# {'ENSG00000275989.1', 'ENSG00000201231.1', 'ENSG00000258375.2', 'ENSG00000248715.2', 'ENSG00000279021.1', 'ENSG00000238783.1', 'ENSG00000131459.12', 'ENSG00000268105.1', 'ENSG00000230834.1', 'ENSG00000223612.3', 'ENSG00000165997.4', 'ENSG00000225971.1', 'ENSG00000241035.2', 'ENSG00000261435.1', 'ENSG00000251549.2', 'ENSG00000201263.1', 'ENSG00000122254.6', 'ENSG00000253102.1', 'ENSG00000137648.17', 'ENSG00000233337.1', 'ENSG00000185594.5', 'ENSG00000250984.1', 'ENSG00000258443.1', 'ENSG00000222724.1', 'ENSG00000223603.1', 'ENSG00000276866.1', 'ENSG00000278899.1', 'ENSG00000233643.2', 'ENSG00000222616.1', 'ENSG00000260989.1', 'ENSG00000202041.1', 'ENSG00000171243.7', 'ENSG00000285627.1', 'ENSG00000144369.12', 'ENSG00000254769.3', 'ENSG00000255225.1', 'ENSG00000206977.1', 'ENSG00000197866.3', 'ENSG00000260251.1', 'ENSG00000219133.2', 'ENSG00000226356.2', 'ENSG00000219387.2', 'ENSG00000239744.3', 'ENSG00000278348.1', 'ENSG00000225083.1', 'ENSG00000249721.1', 'ENSG00000278847.1', 'ENSG00000235056.1', 'ENSG00000101447.14', 'ENSG00000243349.2', 'ENSG00000233838.5', 'ENSG00000244461.1', 'ENSG00000221962.5', 'ENSG00000272159.1', 'ENSG00000049247.13', 'ENSG00000221845.4', 'ENSG00000252848.1', 'ENSG00000182901.16', 'ENSG00000265164.1', 'ENSG00000249199.1', 'ENSG00000263882.2', 'ENSG00000225689.1', 'ENSG00000276507.1', 'ENSG00000268101.2', 'ENSG00000258125.1', 'ENSG00000270666.1', 'ENSG00000229750.1', 'ENSG00000126709.14', 'ENSG00000271776.1', 'ENSG00000140043.11', 'ENSG00000176855.11', 'ENSG00000207611.1', 'ENSG00000250127.1', 'ENSG00000276850.4', 'ENSG00000283334.1', 'ENSG00000234064.1', 'ENSG00000283571.1', 'ENSG00000235446.2', 'ENSG00000239365.2', 'ENSG00000207571.1', 'ENSG00000215480.4', 'ENSG00000281039.1', 'ENSG00000285915.1', 'ENSG00000242244.1', 'ENSG00000277435.1', 'ENSG00000226061.1', 'ENSG00000266828.2', 'ENSG00000173452.13', 'ENSG00000261670.1', 'ENSG00000271550.1', 'ENSG00000235690.2', 'ENSG00000200849.1', 'ENSG00000205918.9', 'ENSG00000257493.1', 'ENSG00000263643.1', 'ENSG00000242766.1', 'ENSG00000263963.1', 'ENSG00000172215.5', 'ENSG00000186908.14', 'ENSG00000200293.1', 'ENSG00000251195.1', 'ENSG00000244534.3', 'ENSG00000251113.2', 'ENSG00000219757.1', 'ENSG00000263746.1', 'ENSG00000248968.1', 'ENSG00000221255.1', 'ENSG00000250624.1', 'ENSG00000253821.1', 'ENSG00000144283.21', 'ENSG00000222345.1', 'ENSG00000262067.1', 'ENSG00000244756.1', 'ENSG00000271153.1', 'ENSG00000225551.1', 'ENSG00000229334.1', 'ENSG00000223544.1', 'ENSG00000235308.1', 'ENSG00000276789.1', 'ENSG00000211851.1', 'ENSG00000141934.9', 'ENSG00000251788.1', 'ENSG00000237247.6', 'ENSG00000257725.1', 'ENSG00000262831.1', 'ENSG00000231878.1', 'ENSG00000258482.1', 'ENSG00000169375.15', 'ENSG00000203266.2', 'ENSG00000284736.1', 'ENSG00000225655.5', 'ENSG00000275940.1', 'ENSG00000167617.2', 'ENSG00000134198.9', 'ENSG00000201736.1', 'ENSG00000275497.1', 'ENSG00000280352.1', 'ENSG00000200492.2', 'ENSG00000264315.1', 'ENSG00000067560.10', 'ENSG00000196468.7', 'ENSG00000184560.7', 'ENSG00000229560.1', 'ENSG00000224280.1', 'ENSG00000251574.6', 'ENSG00000250360.1', 'ENSG00000234521.2', 'ENSG00000214628.3', 'ENSG00000212424.1', 'ENSG00000233917.8', 'ENSG00000186766.7', 'ENSG00000223554.1', 'ENSG00000279953.1', 'ENSG00000275597.1', 'ENSG00000081307.12', 'ENSG00000248867.1', 'ENSG00000284377.1', 'ENSG00000228216.1', 'ENSG00000251435.1', 'ENSG00000240056.2', 'ENSG00000236025.1', 'ENSG00000224887.1', 'ENSG00000284718.1', 'ENSG00000271400.1', 'ENSG00000254650.1', 'ENSG00000278346.1', 'ENSG00000257415.1', 'ENSG00000243770.3', 'ENSG00000261831.2', 'ENSG00000235274.1', 'ENSG00000240174.1', 'ENSG00000236604.1', 'ENSG00000213153.3', 'ENSG00000207927.1', 'ENSG00000179941.7', 'ENSG00000169247.12', 'ENSG00000201752.1', 'ENSG00000160181.8', 'ENSG00000146352.12', 'ENSG00000235243.1', 'ENSG00000250667.1', 'ENSG00000236999.1', 'ENSG00000176510.5', 'ENSG00000236932.2', 'ENSG00000200829.1', 'ENSG00000213926.3', 'ENSG00000225271.1', 'ENSG00000264540.2', 'ENSG00000274625.1', 'ENSG00000237 ...

# %%
method_collection = {
    'ANOVA': {
        'score': anova_scores,
        'genes': anova_selected_genes
    },
    'Chi-Squared': {
        'score': chi2_scores,
        'genes': chi2_selected_genes
    },
    'Mutual Information': {
        'score': mutual_info_scores,
        'genes': mutual_info_selected_genes
    },
    'Fisher\'s Score': {
        'score': fisher_score,
        'genes': fisher_selected_genes
    }
}

# %%
all_selected_genes = set()
for method in method_collection.values():
    all_selected_genes.update(method["genes"])

# %%
comparison = pd.DataFrame(index=list(all_selected_genes))

# %%
for method_name, results in method_collection.items():
    comparison[method_name] = 0
    comparison.loc[results['genes'], method_name] = 1
comparison['Times_Selected'] = comparison.sum(axis=1)

# %%
n_methods = len(method_collection)
consensus_genes = comparison[comparison['Times_Selected'] == n_methods]
print(f"Genes selected by ALL methods: {len(consensus_genes)}")
# Out:
# Genes selected by ALL methods: 2176

# %%
consensus_genes
# Out:
#                    ANOVA  Chi-Squared  Mutual Information  Fisher's Score  \
# ENSG00000201231.1      1            1                   1               1
# ENSG00000255225.1      1            1                   1               1
# ENSG00000278847.1      1            1                   1               1
# ENSG00000235056.1      1            1                   1               1
# ENSG00000272159.1      1            1                   1               1
# ...                  ...          ...                 ...             ...
# ENSG00000244222.2      1            1                   1               1
# ENSG00000249257.1      1            1                   1               1
# ENSG00000229486.2      1            1                   1               1
# ENSG00000282358.1      1            1                   1               1
# ENSG00000227062.2      1            1                   1               1
#
#                    Times_Selected
# ENSG00000201231.1               4
# ENSG00000255225.1               4
# ENSG00000278847.1               4
# ENSG00000235056.1               4
# ENSG00000272159.1               4
# ...                           ...
# ENSG00000244222.2               4
# ENSG00000249257.1               4
# ENSG00000229486.2               4
# ENSG00000282358.1               4
# ENSG00000227062.2               4
#
# [2176 rows x 5 columns]

# %%
symbol_ensembl_mapping = ppmi_ad.varm['symbol_ensembl_mapping'].loc[consensus_genes.index,:]['gene_symbol']

# %%
importance_df = pd.DataFrame(index=consensus_genes.index)

# %% [markdown]
# ### Importance Scores

# %%
import math

def plot_feature_importances(method_collection, consensus_genes, symbol_ensembl_mapping):
    plt.figure(figsize=(15, 16))
    idx = 1
    for method_name, results in method_collection.items():
        df = pd.DataFrame({
            'Gene': selected_genes,
            'Score': results['score']
        })
        df_consensus = df[df['Gene'].isin(consensus_genes.index)]
        df_consensus = df_consensus.merge(
            symbol_ensembl_mapping.rename('gene_symbol'),
            left_on='Gene',
            right_index=True,
            how='left'
        )
        df_consensus = df_consensus.sort_values('Score', ascending=False)
        sns.set_style("whitegrid")
        subplot_row_count = math.ceil(len(method_collection) / 2)
        plt.subplot(subplot_row_count, 2, idx)
        plt.title(f' (Males 30-50) {method_name}', fontsize=14)
        ax = sns.barplot(
                data=df_consensus,
                x='Score',
                y='gene_symbol',
                palette="Blues_d",
                orient='h',
                dodge=False
            )
        idx += 1
        for i, score in enumerate(df_consensus['Score']):
            score_fmt = f'{score: .4f}' if method_name == 'Mutual Information' else f'{score: .1f}'
            ax.text(score, i, score_fmt, va='center', fontsize=6)
        plt.xticks(fontsize=6)
        plt.yticks(fontsize=6)
    plt.tight_layout
    plt.show()

# %%
import seaborn as sns
plot_feature_importances(method_collection, consensus_genes.head(40), symbol_ensembl_mapping)
# Out:
# /var/folders/qb/t7qv2b9n33n2xzbjvg_dk_4c0000gn/T/ipykernel_9171/4214355860.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# /var/folders/qb/t7qv2b9n33n2xzbjvg_dk_4c0000gn/T/ipykernel_9171/4214355860.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# /var/folders/qb/t7qv2b9n33n2xzbjvg_dk_4c0000gn/T/ipykernel_9171/4214355860.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# /var/folders/qb/t7qv2b9n33n2xzbjvg_dk_4c0000gn/T/ipykernel_9171/4214355860.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
consensus_gene_symbols = symbol_ensembl_mapping[consensus_genes.index].to_frame()

# %% [markdown]
# ### Enrichment of Consensus Genes

# %%
import gseapy as gp

# %%
enr = gp.enrichr(gene_list=consensus_gene_symbols['gene_symbol'].to_list(),
                 gene_sets=['MSigDB_Hallmark_2020',
                            'KEGG_2021_Human',
                            'WikiPathways_2024_Human',
                            'Human_Phenotype_Ontology',
                            'GO_Biological_Process_2023',
                            'GO_Molecular_Function_2023',
                            'GO_Cellular_Component_2023',
                            'SynGO_2024',
                            'OMIM_Disease'],
                 organism='human')

# %%
enr.results
# Out:
#                   Gene_set                        Term Overlap   P-value  \
# 0     MSigDB_Hallmark_2020  Wnt-beta Catenin Signaling    4/42  0.667540
# 1     MSigDB_Hallmark_2020   Interferon Alpha Response    7/97  0.902929
# 2     MSigDB_Hallmark_2020                Angiogenesis    2/36  0.908376
# 3     MSigDB_Hallmark_2020             Notch Signaling    1/32  0.972850
# 4     MSigDB_Hallmark_2020          Hedgehog Signaling    1/36  0.982709
# ...                    ...                         ...     ...       ...
# 3553          OMIM_Disease              cardiomyopathy    1/42  0.991213
# 3554          OMIM_Disease                    myopathy    1/44  0.992988
# 3555          OMIM_Disease                    diabetes    2/75  0.997889
# 3556          OMIM_Disease           diabetes mellitus    1/58  0.998555
# 3557          OMIM_Disease                    leukemia    1/78  0.999846
#
#       Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0             0.999996            0                     0    0.882903
# 1             0.999996            0                     0    0.651384
# 2             0.999996            0                     0    0.493034
# 3             0.999996            0                     0    0.270292
# 4             0.999996            0                     0    0.239348
# ...                ...          ...                   ...         ...
# 3553          0.999846            0                     0    0.204253
# 3554          0.999846            0                     0    0.194731
# 3555          0.999846            0                     0    0.229130
# 3556          0.999846            0                     0    0.146787
# 3557          0.999846            0                     0    0.108538
#
#       Combined Score                                    Genes
# 0           0.356830                      HEY1;TCF7;CUL1;FZD8
# 1           0.066513  BST2;ISG15;LAP3;CD47;DDX60;IFIT3;IFI44L
# 2           0.047379                               SPP1;FGFR1
# 3           0.007440                                     CUL1
# 4           0.004175                                     HEY1
# ...              ...                                      ...
# 3553        0.001803                                      TTN
# 3554        0.001370                                      TTN
# 3555        0.000484                                LIPC;AQP2
# 3556        0.000212                                     LIPC
# 3557        0.000017                                     TAL2
#
# [3558 rows x 10 columns]

# %%
enr_res_pivot = enr.results.pivot(index='Term', columns='Genes', values='P-value')
enr_res_pivot = enr_res_pivot.fillna(1.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(
    enr_res_pivot,
    cmap='flare',
    fmt='.3f',
    vmin=0, vmax=1
)
plt.title("GSEA Results of Consensus Genes for Males Aged 30-50")
# Out:
# Text(0.5, 1.0, 'GSEA Results of Consensus Genes for Males Aged 30-50')

# %%
symbol_ensembl_mapping.head()
# Out:
# ENSG00000201231.1           RNU4-50P
# ENSG00000255225.1             OR8B6P
# ENSG00000278847.1    ENSG00000278847
# ENSG00000235056.1    ENSG00000235056
# ENSG00000272159.1    ENSG00000272159
#                           ...
# ENSG00000244222.2           OR7E121P
# ENSG00000249257.1    ENSG00000249257
# ENSG00000229486.2    ENSG00000229486
# ENSG00000282358.1    ENSG00000282358
# ENSG00000227062.2    ENSG00000227062
# Name: gene_symbol, Length: 2176, dtype: object

# %%
symbol_ensembl_mapping.to_csv("/Users/kpax/Documents/aep/study/MSC/lab/PPMI_Project_133_RNASeq/feature_selection_intersection_consensus_males_30-50.csv")
